# %% [markdown]
# # USIU Multi-Agent Student Support System - Demo
#
# **Lab 2 Assignment: Building a Multi-Agent AI System**
#
# This notebook demonstrates the multi-agent chatbot system for USIU student support.
#
# ## System Architecture
#
# - **Framework**: LangGraph (hierarchical supervisor pattern)
# - **LLM**: Claude Sonnet 4 (Anthropic)
# - **Agents**: 7 specialized agents
# - **Coordination**: Supervisor-worker pattern with shared state

# %% [markdown]
# ## Setup and Installation

# %%
# Install required packages (uncomment if needed)
# !pip install langgraph langchain langchain-anthropic anthropic python-dotenv

# %%
import os
from dotenv import load_dotenv

# Load environment variables
load_dotenv()

# Verify API key is set
if not os.getenv('ANTHROPIC_API_KEY'):
    print("⚠️  Warning: ANTHROPIC_API_KEY not found in environment")
    print("Please set it in .env file or export it:")
    print("export ANTHROPIC_API_KEY='your-api-key-here'")
else:
    print("✅ API key loaded successfully")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 2
#       1 import os
# ----> 2 from dotenv import load_dotenv
#       4 # Load environment variables
#       5 load_dotenv()
#
# ModuleNotFoundError: No module named 'dotenv'

# %% [markdown]
# ## Import the Multi-Agent System

# %%
# %pip install langchain

from usiu_multiagent_system import (
    create_usiu_workflow,
    run_usiu_chatbot,
    USIUAgentTeam,
    USIU_KNOWLEDGE_BASE
)
from langchain_core.messages import HumanMessage

print("✅ Multi-agent system imported successfully")
# Out:
# ^C
# Note: you may need to restart the kernel to use updated packages.
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 3
#       1 get_ipython().run_line_magic('pip', 'install langchain')
# ----> 3 from usiu_multiagent_system import (
#       4     create_usiu_workflow,
#       5     run_usiu_chatbot,
#       6     USIUAgentTeam,
#       7     USIU_KNOWLEDGE_BASE
#       8 )
#       9 from langchain_core.messages import HumanMessage
#      11 print("✅ Multi-agent system imported successfully")
#
# File c:\Users\PC\OneDrive - United States International University (USIU)\Desktop\Spring Semester 2026\Artificial Intelligence\MULTI AGENT ASSIGNMENT\usiu_multiagent_system.py:21
#      19 from typing import Annotated, TypedDict, Sequence
#      20 from typing_extensions import TypedDict
# ---> 21 from langgraph.graph import StateGraph, END
#      22 from langchain_core.messages import BaseMessage, HumanMessage, AIMessage, SystemMessage
#      23 from langchain_anthropic import ChatAnthropic
#
# ModuleNotFoundError: No module named 'langgraph'
# Collecting langchain
#   Using cached langchain-1.2.7-py3-none-any.whl.metadata (4.9 kB)
# Collecting langchain-core<2.0.0,>=1.2.7 (from langchain)
#   Using cached langchain_core-1.2.7-py3-none-any.whl.metadata (3.7 kB)
# Collecting langgraph<1.1.0,>=1.0.7 (from langchain)
#   Using cached langgraph-1.0.7-py3-none-any.whl.metadata (7.4 kB)
# Collecting pydantic<3.0.0,>=2.7.4 (from langchain)
#   Using cached pydantic-2.12.5-py3-none-any.whl.metadata (90 kB)
# Collecting jsonpatch<2.0.0,>=1.33.0 (from langchain-core<2.0.0,>=1.2.7->langchain)
#   Using cached jsonpatch-1.33-py2.py3-none-any.whl.metadata (3.0 kB)
# Collecting langsmith<1.0.0,>=0.3.45 (from langchain-core<2.0.0,>=1.2.7->langchain)
#   Using cached langsmith-0.6.7-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: packaging<26.0.0,>=23.2.0 in c:\users\pc\appdata\local\programs\python\python312\lib\site-packages (from langchain-core<2.0.0,>=1.2.7->langchain) (24.2)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in c:\users\pc\appdata\local\programs\python\python312\lib\site-packages (from langchain-core<2.0.0,>=1.2.7->langchain) (6.0.2)
# Collecting tenacity!=8.4.0,<10.0.0,>=8.1.0 (from langchain-core<2.0.0,>=1.2.7->langchain)
#   Using cached tenacity-9.1.2-py3-none-any.whl.metadata (1.2 kB)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in c:\users\pc\appdata\local\programs\python\python312\lib\site-packages (from langchain-core<2.0.0,>=1.2.7->langchain) (4.14.1)
# Collecting uuid-utils<1.0,>=0.12.0 (from langchain-core<2.0.0,>=1.2.7->langchain)
#   Using cached uuid_utils-0.14.0-cp39-abi3-win_amd64.whl.metadata (5.0 kB)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\pc\appdata\local\programs\python\python312\lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.2.7->langchain) (3.0.0)
# Collecting langgraph-checkpoint<5.0.0,>=2.1.0 (from langgraph<1.1.0,>=1.0.7->langchain)
#   Using cached langgraph_checkpoint-4.0.0-py3-none-any.whl.metadata (4.9 kB)
# Collecting langgraph-prebuilt<1.1.0,>=1.0.7 (from langgraph<1.1.0,>=1.0.7->langchain)
#   Using cached langgraph_prebuilt-1.0.7-py3-none-any.whl.metadata (5.2 kB)
# Collecting langgraph-sdk<0.4.0,>=0.3.0 (from langgraph<1.1.0,>=1.0.7->langchain)
#   Using cached langgraph_sdk-0.3.3-py3-none-any.whl.metadata (1.6 kB)
# Collecting xxhash>=3.5.0 (from langgraph<1.1.0,>=1.0.7->langchain)
#   Downloading xxhash-3.6.0-cp312-cp312-win_amd64.whl.metadata (13 kB)
# Collecting ormsgpack>=1.12.0 (from langgraph-checkpoint<5.0.0,>=2.1.0->langgraph<1.1.0,>=1.0.7->langchain)
#   Downloading ormsgpack-1.12.2-cp312-cp312-win_amd64.whl.metadata (3.3 kB)
# Requirement already satisfied: httpx>=0.25.2 in c:\users\pc\appdata\local\programs\python\python312\lib\site-packages (from langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.1.0,>=1.0.7->langchain) (0.27.2)
# Collecting orjson>=3.10.1 (from langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.1.0,>=1.0.7->langchain)
#   Downloading orjson-3.11.6-cp312-cp312-win_amd64.whl.metadata (43 kB)
# Collecting requests-toolbelt>=1.0.0 (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.7->langchain)
#   Using cached requests_toolbelt-1.0.0-py2.py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: requests>=2.0.0 in c:\users\pc\appdata\local\programs\python\python312\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.7->langchain) (2.32.3)
# Collecting zstandard>=0.23.0 (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.7->langchain)
#   Downloading zstandard-0.25.0-cp312-cp312-win_amd64.whl.metadata (3.3 kB)
# Requirement already satisfied: anyio in c:\users\pc\appdata\local\programs\python\python312\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.1.0,>=1.0.7->langchain) (4.6.2.post1)
# Requirement already satisfied: certifi in c:\users\pc\appdata\local\programs\python\python312\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.1.0,>=1.0.7->langchain) (2024.8.30)
# Requirement already satisfied: httpcore==1.* in c:\users\pc\appdata\local\programs\python\python312\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.1.0,>=1.0.7->langchain) (1.0.7)
# Requirement already satisfied: idna in c:\users\pc\appdata\local\programs\python\python312\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.1.0,>=1.0.7->langchain) (3.10)
# Requirement already satisfied: sniffio in c:\users\pc\appdata\local\programs\python\python312\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.1.0,>=1.0.7->langchain) (1.3.1)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\pc\appdata\local\programs\python\python312\lib\site-packages (from httpcore==1.*->httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.1.0,>=1.0.7->langchain) (0.14.0)
# Collecting annotated-types>=0.6.0 (from pydantic<3.0.0,>=2.7.4->langchain)
#   Using cached annotated_types-0.7.0-py3-none-any.whl.metadata (15 kB)
# Collecting pydantic-core==2.41.5 (from pydantic<3.0.0,>=2.7.4->langchain)
#   Downloading pydantic_core-2.41.5-cp312-cp312-win_amd64.whl.metadata (7.4 kB)
# Collecting typing-inspection>=0.4.2 (from pydantic<3.0.0,>=2.7.4->langchain)
#   Using cached typing_inspection-0.4.2-py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\pc\appdata\local\programs\python\python312\lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.7->langchain) (3.4.0)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\pc\appdata\local\programs\python\python312\lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.7->langchain) (2.2.3)
# Using cached langchain-1.2.7-py3-none-any.whl (108 kB)
# Using cached langchain_core-1.2.7-py3-none-any.whl (490 kB)
# Using cached jsonpatch-1.33-py2.py3-none-any.whl (12 kB)
# Using cached langgraph-1.0.7-py3-none-any.whl (157 kB)
# Using cached langgraph_checkpoint-4.0.0-py3-none-any.whl (46 kB)
# Using cached langgraph_prebuilt-1.0.7-py3-none-any.whl (35 kB)
# Using cached langgraph_sdk-0.3.3-py3-none-any.whl (67 kB)
# Using cached langsmith-0.6.7-py3-none-any.whl (309 kB)
# Using cached pydantic-2.12.5-py3-none-any.whl (463 kB)
# Downloading pydantic_core-2.41.5-cp312-cp312-win_amd64.whl (2.0 MB)
#    ---------------------------------------- 0.0/2.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.0 MB ? eta -:--:--
#    ----- ---------------------------------- 0.3/2.0 MB ? eta -:--:--
#    --------------- ------------------------ 0.8/2.0 MB 2.8 MB/s eta 0:00:01
#    ---------------------------------------- 2.0/2.0 MB 4.2 MB/s  0:00:00
# Using cached tenacity-9.1.2-py3-none-any.whl (28 kB)
# Using cached uuid_utils-0.14.0-cp39-abi3-win_amd64.whl (182 kB)
# Using cached annotated_types-0.7.0-py3-none-any.whl (13 kB)
# Downloading orjson-3.11.6-cp312-cp312-win_amd64.whl (136 kB)
# Downloading ormsgpack-1.12.2-cp312-cp312-win_amd64.whl (117 kB)
# Using cached requests_toolbelt-1.0.0-py2.py3-none-any.whl (54 kB)
# Using cached typing_inspection-0.4.2-py3-none-any.whl (14 kB)
# Downloading xxhash-3.6.0-cp312-cp312-win_amd64.whl (31 kB)
# Downloading zstandard-0.25.0-cp312-cp312-win_amd64.whl (506 kB)
# Installing collected packages: zstandard, xxhash, uuid-utils, typing-inspection, tenacity, pydantic-core, ormsgpack, orjson, jsonpatch, annotated-types, requests-toolbelt, pydantic, langsmith, langgraph-sdk, langchain-core, langgraph-checkpoint, langgraph-prebuilt, langgraph, langchain
#
#    -- -------------------------------------  1/19 [xxhash]
#    ------ ---------------------------------  3/19 [typing-inspection]
#    -------- -------------------------------  4/19 [tenacity]
#    -------- -------------------------------  4/19 [tenacity]
#    -------- -------------------------------  4/19 [tenacity]
#    ---------- -----------------------------  5/19 [pydantic-core]
#    ------------ ---------------------------  6/19 [ormsgpack]
#    -------------- -------------------------  7/19 [orjson]
#    ---------------- -----------------------  8/19 [jsonpatch]
#    ---------------- -----------------------  8/19 [jsonpatch]
#    --------------------- ------------------ 10/19 [requests-toolbelt]
#    --------------------- ------------------ 10/19 [requests-toolbelt]
#    --------------------- ------------------ 10/19 [requests-toolbelt]
#    --------------------- ------------------ 10/19 [requests-toolbelt]
#    --------------------- ------------------ 10/19 [requests-toolbelt]
#    --------------------- ------------------ 10/19 [requests-toolbelt]
#    --------------------- ------------------ 10/19 [requests-toolbelt]
#    ----------------------- ---------------- 11/19 [pydantic]
#    ----------------------- ---------------- 11/19 [pydantic]
#    ----------------------- ---------------- 11/19 [pydantic]
#    ----------------------- ---------------- 11/19 [pydantic]
#    ----------------------- ---------------- 11/19 [pydantic]
#    ----------------------- ---------------- 11/19 [pydantic]
#    ----------------------- ---------------- 11/19 [pydantic]
#    ----------------------- ---------------- 11/19 [pydantic]
#    ----------------------- ---------------- 11/19 [pydantic]
#    ----------------------- ---------------- 11/19 [pydantic]
#    ----------------------- ---------------- 11/19 [pydantic]
#    ----------------------- ---------------- 11/19 [pydantic]
#    ----------------------- ---------------- 11/19 [pydantic]
#    ----------------------- ---------------- 11/19 [pydantic]
#    ----------------------- ---------------- 11/19 [pydantic]
#    ----------------------- ---------------- 11/19 [pydantic]
#    ----------------------- ---------------- 11/19 [pydantic]
#    ------------------------- -------------- 12/19 [langsmith]
#    ------------------------- -------------- 12/19 [langsmith]
#    ------------------------- -------------- 12/19 [langsmith]
#    ------------------------- -------------- 12/19 [langsmith]
#    ------------------------- -------------- 12/19 [langsmith]
#    ------------------------- -------------- 12/19 [langsmith]
#    ------------------------- -------------- 12/19 [langsmith]
#    ------------------------- -------------- 12/19 [langsmith]
#    ------------------------- -------------- 12/19 [langsmith]
#    ------------------------- -------------- 12/19 [langsmith]
#    ------------------------- -------------- 12/19 [langsmith]
#    ------------------------- -------------- 12/19 [langsmith]
#    ------------------------- -------------- 12/19 [langsmith]
#    --------------------------- ------------ 13/19 [langgraph-sdk]
#    --------------------------- ------------ 13/19 [langgraph-sdk]
#    --------------------------- ------------ 13/19 [langgraph-sdk]
#    ----------------------------- ---------- 14/19 [langchain-core]
#    ----------------------------- ---------- 14/19 [langchain-core]
#    ----------------------------- ---------- 14/19 [langchain-core]
#    ----------------------------- ---------- 14/19 [langchain-core]
#    ----------------------------- ---------- 14/19 [langchain-core]
#    ----------------------------- ---------- 14/19 [langchain-core]
#    ----------------------------- ---------- 14/19 [langchain-core]
#    ----------------------------- ---------- 14/19 [langchain-core]
#    ----------------------------- ---------- 14/19 [langchain-core]
#    ----------------------------- ---------- 14/19 [langchain-core]
#    ----------------------------- ---------- 14/19 [langchain-core]
#    ----------------------------- ---------- 14/19 [langchain-core]
#    ----------------------------- ---------- 14/19 [langchain-core]
#    ----------------------------- ---------- 14/19 [langchain-core]
#    ----------------------------- ---------- 14/19 [langchain-core]
#    ----------------------------- ---------- 14/19 [langchain-core]
#    ----------------------------- ---------- 14/19 [langchain-core]
#    ----------------------------- ---------- 14/19 [langchain-core]
#    ----------------------------- ---------- 14/19 [langchain-core]
#    ----------------------------- ---------- 14/19 [langchain-core]
#    ----------------------------- ---------- 14/19 [langchain-core]
#    ----------------------------- ---------- 14/19 [langchain-core]
#    ----------------------------- ---------- 14/19 [langchain-core]
#    ----------------------------- ---------- 14/19 [langchain-core]
#    ----------------------------- ---------- 14/19 [langchain-core]
#    ----------------------------- ---------- 14/19 [langchain-core]
#    ----------------------------- ---------- 14/19 [langchain-core]
#    ----------------------------- ---------- 14/19 [langchain-core]
#    ----------------------------- ---------- 14/19 [langchain-core]
#    ----------------------------- ---------- 14/19 [langchain-core]
#    ----------------------------- ---------- 14/19 [langchain-core]
#    ----------------------------- ---------- 14/19 [langchain-core]
#    ----------------------------- ---------- 14/19 [langchain-core]
#    ------------------------------- -------- 15/19 [langgraph-checkpoint]
#    ------------------------------- -------- 15/19 [langgraph-checkpoint]
#    ------------------------------- -------- 15/19 [langgraph-checkpoint]
#    --------------------------------- ------ 16/19 [langgraph-prebuilt]
#    ----------------------------------- ---- 17/19 [langgraph]
#    ----------------------------------- ---- 17/19 [langgraph]
#    ----------------------------------- ---- 17/19 [langgraph]
#    ----------------------------------- ---- 17/19 [langgraph]
#    ----------------------------------- ---- 17/19 [langgraph]
#    ----------------------------------- ---- 17/19 [langgraph]
#    ----------------------------------- ---- 17/19 [langgraph]
#    ----------------------------------- ---- 17/19 [langgraph]
#    ----------------------------------- ---- 17/19 [langgraph]
#    ----------------------------------- ---- 17/19 [langgraph]
#    ------------------------------------- -- 18/19 [langchain]
#    ------------------------------------- -- 18/19 [langchain]
#    ------------------------------------- -- 18/19 [langchain]
#    ------------------------------------- -- 18/19 [langchain]
#    ------------------------------------- -- 18/19 [langchain]
#    ------------------------------------- -- 18/19 [langchain]
#    ------------------------------------- -- 18/19 [langchain]
#    ---------------------------------------- 19/19 [langchain]
#
# Successfully installed annotated-types-0.7.0 jsonpatch-1.33 langchain-1.2.7 langchain-core-1.2.7 langgraph-1.0.7 langgraph-checkpoint-4.0.0 langgraph-prebuilt-1.0.7 langgraph-sdk-0.3.3 langsmith-0.6.7 orjson-3.11.6 ormsgpack-1.12.2 pydantic-2.12.5 pydantic-core-2.41.5 requests-toolbelt-1.0.0 tenacity-9.1.2 typing-inspection-0.4.2 uuid-utils-0.14.0 xxhash-3.6.0 zstandard-0.25.0
# [notice] A new release of pip is available: 25.2 -> 26.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# ## Inspect the Knowledge Base

# %%
import json

print("📚 USIU Knowledge Base Structure:")
print(json.dumps({
    category: list(data.keys()) 
    for category, data in USIU_KNOWLEDGE_BASE.items()
}, indent=2))

# %% [markdown]
# ## Demo 1: Academic Query - Registration Deadline
#
# This demonstrates the agent workflow for academic queries.

# %%
query1 = "When is the registration deadline for Spring 2026?"
print(f"\n{'='*70}")
print(f"DEMO 1: Academic Query")
print(f"{'='*70}")
print(f"\n📝 Student Query: {query1}\n")

result1 = run_usiu_chatbot(query1)

# %% [markdown]
# ### Expected Agent Flow:
# 1. **Greeter Agent** → Classifies intent as "academic"
# 2. **Academic Advisor Agent** → Retrieves registration deadlines
# 3. **Quality Reviewer** → Validates response accuracy
# 4. **Response Delivered** → Complete answer with actionable steps

# %% [markdown]
# ## Demo 2: Financial Query - Tuition and Scholarships

# %%
query2 = "How much is tuition per credit hour and what scholarships are available?"
print(f"\n{'='*70}")
print(f"DEMO 2: Financial Query")
print(f"{'='*70}")
print(f"\n📝 Student Query: {query2}\n")

result2 = run_usiu_chatbot(query2)

# %% [markdown]
# ### Expected Agent Flow:
# 1. **Greeter Agent** → Classifies intent as "finance"
# 2. **Finance Agent** → Retrieves tuition rates and scholarship info
# 3. **Quality Reviewer** → Validates financial information
# 4. **Response Delivered** → Comprehensive financial guidance

# %% [markdown]
# ## Demo 3: IT Support Query - Portal Access

# %%
query3 = "I can't access my student portal. What should I do?"
print(f"\n{'='*70}")
print(f"DEMO 3: IT Support Query")
print(f"{'='*70}")
print(f"\n📝 Student Query: {query3}\n")

result3 = run_usiu_chatbot(query3)

# %% [markdown]
# ### Expected Agent Flow:
# 1. **Greeter Agent** → Classifies intent as "it_support"
# 2. **IT Support Agent** → Provides troubleshooting steps
# 3. **Quality Reviewer** → Checks if escalation needed
# 4. **Response Delivered** OR **Escalation** if complex

# %% [markdown]
# ## Demo 4: Student Life Query

# %%
query4 = "What student clubs are available at USIU?"
print(f"\n{'='*70}")
print(f"DEMO 4: Student Life Query")
print(f"{'='*70}")
print(f"\n📝 Student Query: {query4}\n")

result4 = run_usiu_chatbot(query4)

# %% [markdown]
# ## Interactive Testing
#
# Try your own queries below!

# %%
# Custom query
custom_query = input("Enter your question: ")
result = run_usiu_chatbot(custom_query)

# %% [markdown]
# ## Agent Workflow Visualization
#
# Let's visualize the agent workflow graph.

# %%
# Create the workflow
app = create_usiu_workflow()

# Visualize graph (requires graphviz)
try:
    from IPython.display import Image, display
    display(Image(app.get_graph().draw_mermaid_png()))
except Exception as e:
    print(f"Graph visualization not available: {e}")
    print("\nAgent workflow:")
    print("START → Greeter → [Academic/Finance/Student Life/IT] → Quality Reviewer → END")

# %% [markdown]
# ## Performance Analysis

# %%
import time

test_queries = [
    "When is registration?",
    "How much is tuition?",
    "Portal login issues",
    "Student clubs?",
]

print("\n📊 Performance Testing\n")
print(f"{'Query':<30} | {'Time (s)':<10} | {'Intent':<15}")
print("-" * 60)

for query in test_queries:
    start = time.time()
    result = run_usiu_chatbot(query)
    elapsed = time.time() - start
    
    # Extract intent from result
    intent = "N/A"
    for agent_name, state in result.items():
        if 'intent' in state:
            intent = state['intent']
            break
    
    print(f"{query:<30} | {elapsed:<10.2f} | {intent:<15}")

# %% [markdown]
# ## Key Takeaways
#
# ### Multi-Agent Advantages:
# 1. **Specialization**: Each agent is expert in their domain
# 2. **Quality Control**: Built-in review process
# 3. **Scalability**: Easy to add new specialized agents
# 4. **Transparency**: Clear workflow and decision-making
# 5. **Reliability**: Automatic escalation for complex cases
#
# ### Challenges Addressed:
# - **Coordination**: Supervisor pattern prevents chaos
# - **Accuracy**: Quality reviewer validates responses
# - **Cost**: Optimized context windows and routing
# - **Loops**: Iteration limits and explicit termination
# - **Tone**: Consistent guidelines across agents

# %% [markdown]
# ## Conclusion
#
# This multi-agent system demonstrates how specialized AI agents can collaborate to provide superior student support compared to a single generalist agent. The hierarchical supervisor pattern ensures efficient routing, while the quality review step maintains high response standards.
#
# **Next Steps:**
# - Integrate with real USIU database
# - Add web search capability
# - Implement persistent memory
# - Deploy as web service
